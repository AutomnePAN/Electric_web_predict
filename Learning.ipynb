# %% [markdown]
# # Training and Analysing the Data

# %% [markdown]
# ### Import the data set

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import scipy.stats
import matplotlib as plt
import xlrd
import datetime
from sklearn.neural_network import MLPRegressor  # 多层线性回归
from sklearn.preprocessing import minmax_scale
from sklearn import svm
from pandas._libs import tslibs
from sklearn.model_selection import GridSearchCV
import random

# %%
#Import the data_set
raw_data = pd.read_csv('TrainingData/Data_month_with_features_2.csv')

# %%
#The parameters set to test with the MLP
para_set = [[],[],[]]
for a in [10,20,30,40,50,60,70,80,90]:
    for b in [40,50,60,70,80,90,100]:
        para_set[0].append((a,b))
for a in [10,20,30,40,50,60,70,80,90]:
    for b in [40,50,60,70,80,90,100]:
        for c in [40,50,60,70,80,90,100]:
            para_set[1].append((a,b,c))
for a in [10,20,30,40,50,60,70,80,90]:
    for b in [40,50,60,70,80,90,100]:
        for c in [40,50,60,70,80,90,100]:
            for d in [40,50,60,70,80,90,100]:
                para_set[2].append((a,b,c,d))

# %% [markdown]
# ### Set the Training Set

# %%
dataMat = np.array(raw_data)
X = dataMat[51:np.size(dataMat,0)-1,4:]
y = dataMat[51:np.size(dataMat,0)-1,2]
X_sc = minmax_scale(X)
X_train = X_sc[:10000,:]
y_train = y[:10000]
X_test = X_sc[10000:,:]
y_test = y[10000:]

# %% [markdown]
# ## Start Training

# %%
best_score = 0
best_para = (0,0,0)
counter = 0
good_para = []
for para in para_set[1]:
    print(para)
    clf  = MLPRegressor(hidden_layer_sizes=para, activation='relu', solver='adam', alpha=0.0001, batch_size='auto',
                        learning_rate='constant', learning_rate_init=0.01, power_t=0.5, max_iter=2000000, shuffle=True, 
                        random_state=None, tol=1e-8, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
                        early_stopping=False)
    clf.fit(X_train,y_train)
    score = clf.score(X_test, y_test)
    if score > 8.80:
        good_para.append(para);
    if score > best_score:
        best_score = score
        best_predict = clf.predict(X_test)
        best_clf = clf
        best_para = para
    counter = counter + 1
#     print(para)
    print('得分：%.3f' %score)
    print('当前最高的分：%.3f' %best_score)
    print(counter, len(para_set))
# Out:
# (10, 40, 40)
# (10, 40, 40)
# 得分：0.872
# 当前最高的分：0.872
# 1 3
# (10, 40, 50)
# (10, 40, 50)
# 得分：0.870
# 当前最高的分：0.872
# 2 3
# (10, 40, 60)
# (10, 40, 60)
# 得分：0.884
# 当前最高的分：0.884
# 3 3
# (10, 40, 70)
# (10, 40, 70)
# 得分：0.853
# 当前最高的分：0.884
# 4 3
# (10, 40, 80)
# (10, 40, 80)
# 得分：0.857
# 当前最高的分：0.884
# 5 3
# (10, 40, 90)
# (10, 40, 90)
# 得分：0.852
# 当前最高的分：0.884
# 6 3
# (10, 40, 100)
# (10, 40, 100)
# 得分：0.650
# 当前最高的分：0.884
# 7 3
# (10, 50, 40)
# (10, 50, 40)
# 得分：0.873
# 当前最高的分：0.884
# 8 3
# (10, 50, 50)
# (10, 50, 50)
# 得分：0.867
# 当前最高的分：0.884
# 9 3
# (10, 50, 60)
# (10, 50, 60)
# 得分：0.855
# 当前最高的分：0.884
# 10 3
# (10, 50, 70)
# (10, 50, 70)
# 得分：0.868
# 当前最高的分：0.884
# 11 3
# (10, 50, 80)
# (10, 50, 80)
# 得分：0.884
# 当前最高的分：0.884
# 12 3
# (10, 50, 90)
# (10, 50, 90)
# 得分：0.878
# 当前最高的分：0.884
# 13 3
# (10, 50, 100)
# (10, 50, 100)
# 得分：0.839
# 当前最高的分：0.884
# 14 3
# (10, 60, 40)
# (10, 60, 40)
# 得分：0.884
# 当前最高的分：0.884
# 15 3
# (10, 60, 50)
# (10, 60, 50)
# 得分：0.868
# 当前最高的分：0.884
# 16 3
# (10, 60, 60)
# (10, 60, 60)
# 得分：0.887
# 当前最高的分：0.887
# 17 3
# (10, 60, 70)
# (10, 60, 70)
# 得分：0.869
# 当前最高的分：0.887
# 18 3
# (10, 60, 80)
# (10, 60, 80)
# 得分：0.846
# 当前最高的分：0.887
# 19 3
# (10, 60, 90)
# (10, 60, 90)
# 得分：0.878
# 当前最高的分：0.887
# 20 3
# (10, 60, 100)
# (10, 60, 100)
# 得分：0.844
# 当前最高的分：0.887
# 21 3
# (10, 70, 40)
# (10, 70, 40)
# 得分：0.858
# 当前最高的分：0.887
# 22 3
# (10, 70, 50)
# (10, 70, 50)
# 得分：0.843
# 当前最高的分：0.887
# 23 3
# (10, 70, 60)
# (10, 70, 60)
# 得分：0.831
# 当前最高的分：0.887
# 24 3
# (10, 70, 70)
# (10, 70, 70)
# 得分：0.852
# 当前最高的分：0.887
# 25 3
# (10, 70, 80)
# (10, 70, 80)
# 得分：0.882
# 当前最高的分：0.887
# 26 3
# (10, 70, 90)
# (10, 70, 90)
# 得分：0.842
# 当前最高的分：0.887
# 27 3
# (10, 70, 100)
# (10, 70, 100)
# 得分：0.859
# 当前最高的分：0.887
# 28 3
# (10, 80, 40)
# (10, 80, 40)
# 得分：0.877
# 当前最高的分：0.887
# 29 3
# (10, 80, 50)
# (10, 80, 50)
# 得分：0.856
# 当前最高的分：0.887
# 30 3
# (10, 80, 60)
# (10, 80, 60)
# 得分：0.876
# 当前最高的分：0.887
# 31 3
# (10, 80, 70)
# (10, 80, 70)
# 得分：0.873
# 当前最高的分：0.887
# 32 3
# (10, 80, 80)
# (10, 80, 80)
# 得分：0.879
# 当前最高的分：0.887
# 33 3
# (10, 80, 90)
# (10, 80, 90)
# 得分：0.856
# 当前最高的分：0.887
# 34 3
# (10, 80, 100)
# (10, 80, 100)
# 得分：0.867
# 当前最高的分：0.887
# 35 3
# (10, 90, 40)
# (10, 90, 40)
# 得分：0.881
# 当前最高的分：0.887
# 36 3
# (10, 90, 50)
# (10, 90, 50)
# 得分：0.864
# 当前最高的分：0.887
# 37 3
# (10, 90, 60)
# (10, 90, 60)
# 得分：0.878
# 当前最高的分：0.887
# 38 3
# (10, 90, 70)
# (10, 90, 70)
# 得分：0.884
# 当前最高的分：0.887
# 39 3
# (10, 90, 80)
# (10, 90, 80)
# 得分：0.876
# 当前最高的分：0.887
# 40 3
# (10, 90, 90)
# (10, 90, 90)
# 得分：0.877
# 当前最高的分：0.887
# 41 3
# (10, 90, 100)
# (10, 90, 100)
# 得分：0.847
# 当前最高的分：0.887
# 42 3
# (10, 100, 40)
# (10, 100, 40)
# 得分：0.857
# 当前最高的分：0.887
# 43 3
# (10, 100, 50)
# (10, 100, 50)
# 得分：0.853
# 当前最高的分：0.887
# 44 3
# (10, 100, 60)
# (10, 100, 60)
# 得分：0.881
# 当前最高的分：0.887
# 45 3
# (10, 100, 70)
# (10, 100, 70)
# 得分：0.887
# 当前最高的分：0.887
# 46 3
# (10, 100, 80)
# C:\Users\Automne\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# (10, 100, 80)
# 得分：0.882
# 当前最高的分：0.887
# 47 3
# (10, 100, 90)
# (10, 100, 90)
# 得分：0.853
# 当前最高的分：0.887
# 48 3
# (10, 100, 100)
# (10, 100, 100)
# 得分：0.846
# 当前最高的分：0.887
# 49 3
# (20, 40, 40)
# C:\Users\Automne\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# (20, 40, 40)
# 得分：0.880
# 当前最高的分：0.887
# 50 3
# (20, 40, 50)
# (20, 40, 50)
# 得分：0.859
# 当前最高的分：0.887
# 51 3
# (20, 40, 60)
# (20, 40, 60)
# 得分：0.853
# 当前最高的分：0.887
# 52 3
# (20, 40, 70)
# (20, 40, 70)
# 得分：0.855
# 当前最高的分：0.887
# 53 3
# (20, 40, 80)
# (20, 40, 80)
# 得分：0.828
# 当前最高的分：0.887
# 54 3
# (20, 40, 90)
# (20, 40, 90)
# 得分：0.857
# 当前最高的分：0.887
# 55 3
# (20, 40, 100)
# (20, 40, 100)
# 得分：0.860
# 当前最高的分：0.887
# 56 3
# (20, 50, 40)
# (20, 50, 40)
# 得分：0.859
# 当前最高的分：0.887
# 57 3
# (20, 50, 50)
# (20, 50, 50)
# 得分：0.879
# 当前最高的分：0.887
# 58 3
# (20, 50, 60)
# (20, 50, 60)
# 得分：0.837
# 当前最高的分：0.887
# 59 3
# (20, 50, 70)
# (20, 50, 70)
# 得分：0.879
# 当前最高的分：0.887
# 60 3
# (20, 50, 80)
# (20, 50, 80)
# 得分：0.884
# 当前最高的分：0.887
# 61 3
# (20, 50, 90)
# (20, 50, 90)
# 得分：0.877
# 当前最高的分：0.887
# 62 3
# (20, 50, 100)
# (20, 50, 100)
# 得分：0.857
# 当前最高的分：0.887
# 63 3
# (20, 60, 40)
# (20, 60, 40)
# 得分：0.877
# 当前最高的分：0.887
# 64 3
# (20, 60, 50)
# (20, 60, 50)
# 得分：0.867
# 当前最高的分：0.887
# 65 3
# (20, 60, 60)
# (20, 60, 60)
# 得分：0.869
# 当前最高的分：0.887
# 66 3
# (20, 60, 70)
# (20, 60, 70)
# 得分：0.883
# 当前最高的分：0.887
# 67 3
# (20, 60, 80)
# (20, 60, 80)
# 得分：0.864
# 当前最高的分：0.887
# 68 3
# (20, 60, 90)
# (20, 60, 90)
# 得分：0.854
# 当前最高的分：0.887
# 69 3
# (20, 60, 100)
# (20, 60, 100)
# 得分：0.849
# 当前最高的分：0.887
# 70 3
# (20, 70, 40)
# (20, 70, 40)
# 得分：0.857
# 当前最高的分：0.887
# 71 3
# (20, 70, 50)
# (20, 70, 50)
# 得分：0.841
# 当前最高的分：0.887
# 72 3
# (20, 70, 60)
# (20, 70, 60)
# 得分：0.885
# 当前最高的分：0.887
# 73 3
# (20, 70, 70)
# (20, 70, 70)
# 得分：0.871
# 当前最高的分：0.887
# 74 3
# (20, 70, 80)
# (20, 70, 80)
# 得分：0.893
# 当前最高的分：0.893
# 75 3
# (20, 70, 90)
# (20, 70, 90)
# 得分：0.883
# 当前最高的分：0.893
# 76 3
# (20, 70, 100)
# (20, 70, 100)
# 得分：0.888
# 当前最高的分：0.893
# 77 3
# (20, 80, 40)
# (20, 80, 40)
# 得分：0.710
# 当前最高的分：0.893
# 78 3
# (20, 80, 50)
# (20, 80, 50)
# 得分：0.853
# 当前最高的分：0.893
# 79 3
# (20, 80, 60)
# (20, 80, 60)
# 得分：0.838
# 当前最高的分：0.893
# 80 3
# (20, 80, 70)
# (20, 80, 70)
# 得分：0.858
# 当前最高的分：0.893
# 81 3
# (20, 80, 80)
# (20, 80, 80)
# 得分：0.885
# 当前最高的分：0.893
# 82 3
# (20, 80, 90)
# (20, 80, 90)
# 得分：0.827
# 当前最高的分：0.893
# 83 3
# (20, 80, 100)
# (20, 80, 100)
# 得分：0.865
# 当前最高的分：0.893
# 84 3
# (20, 90, 40)
# (20, 90, 40)
# 得分：0.878
# 当前最高的分：0.893
# 85 3
# (20, 90, 50)
# (20, 90, 50)
# 得分：0.864
# 当前最高的分：0.893
# 86 3
# (20, 90, 60)
# (20, 90, 60)
# 得分：0.881
# 当前最高的分：0.893
# 87 3
# (20, 90, 70)
# (20, 90, 70)
# 得分：0.872
# 当前最高的分：0.893
# 88 3
# (20, 90, 80)
# (20, 90, 80)
# 得分：0.842
# 当前最高的分：0.893
# 89 3
# (20, 90, 90)
# (20, 90, 90)
# 得分：0.874
# 当前最高的分：0.893
# 90 3
# (20, 90, 100)
# (20, 90, 100)
# 得分：0.886
# 当前最高的分：0.893
# 91 3
# (20, 100, 40)
# (20, 100, 40)
# 得分：0.845
# 当前最高的分：0.893
# 92 3
# (20, 100, 50)
# (20, 100, 50)
# 得分：0.855
# 当前最高的分：0.893
# 93 3
# (20, 100, 60)
# (20, 100, 60)
# 得分：0.878
# 当前最高的分：0.893
# 94 3
# (20, 100, 70)
# (20, 100, 70)
# 得分：0.888
# 当前最高的分：0.893
# 95 3
# (20, 100, 80)
# (20, 100, 80)
# 得分：0.747
# 当前最高的分：0.893
# 96 3
# (20, 100, 90)
# (20, 100, 90)
# 得分：0.885
# 当前最高的分：0.893
# 97 3
# (20, 100, 100)
# (20, 100, 100)
# 得分：0.874
# 当前最高的分：0.893
# 98 3
# (30, 40, 40)
# (30, 40, 40)
# 得分：0.866
# 当前最高的分：0.893
# 99 3
# (30, 40, 50)
# (30, 40, 50)
# 得分：0.872
# 当前最高的分：0.893
# 100 3
# (30, 40, 60)
# (30, 40, 60)
# 得分：0.842
# 当前最高的分：0.893
# 101 3
# (30, 40, 70)
# (30, 40, 70)
# 得分：0.867
# 当前最高的分：0.893
# 102 3
# (30, 40, 80)
# (30, 40, 80)
# 得分：0.880
# 当前最高的分：0.893
# 103 3
# (30, 40, 90)
# (30, 40, 90)
# 得分：0.845
# 当前最高的分：0.893
# 104 3
# (30, 40, 100)
# (30, 40, 100)
# 得分：0.882
# 当前最高的分：0.893
# 105 3
# (30, 50, 40)
# (30, 50, 40)
# 得分：0.866
# 当前最高的分：0.893
# 106 3
# (30, 50, 50)
# (30, 50, 50)
# 得分：0.861
# 当前最高的分：0.893
# 107 3
# (30, 50, 60)
# (30, 50, 60)
# 得分：0.891
# 当前最高的分：0.893
# 108 3
# (30, 50, 70)
# (30, 50, 70)
# 得分：0.850
# 当前最高的分：0.893
# 109 3
# (30, 50, 80)
# (30, 50, 80)
# 得分：0.812
# 当前最高的分：0.893
# 110 3
# (30, 50, 90)
# (30, 50, 90)
# 得分：0.856
# 当前最高的分：0.893
# 111 3
# (30, 50, 100)
# (30, 50, 100)
# 得分：0.860
# 当前最高的分：0.893
# 112 3
# (30, 60, 40)
# (30, 60, 40)
# 得分：0.866
# 当前最高的分：0.893
# 113 3
# (30, 60, 50)
# (30, 60, 50)
# 得分：0.877
# 当前最高的分：0.893
# 114 3
# (30, 60, 60)
# (30, 60, 60)
# 得分：0.877
# 当前最高的分：0.893
# 115 3
# (30, 60, 70)
# (30, 60, 70)
# 得分：0.869
# 当前最高的分：0.893
# 116 3
# (30, 60, 80)
# (30, 60, 80)
# 得分：0.873
# 当前最高的分：0.893
# 117 3
# (30, 60, 90)
# (30, 60, 90)
# 得分：0.838
# 当前最高的分：0.893
# 118 3
# (30, 60, 100)
# (30, 60, 100)
# 得分：0.869
# 当前最高的分：0.893
# 119 3
# (30, 70, 40)
# (30, 70, 40)
# 得分：0.875
# 当前最高的分：0.893
# 120 3
# (30, 70, 50)
# (30, 70, 50)
# 得分：0.861
# 当前最高的分：0.893
# 121 3
# (30, 70, 60)
# (30, 70, 60)
# 得分：0.858
# 当前最高的分：0.893
# 122 3
# (30, 70, 70)
# (30, 70, 70)
# 得分：0.886
# 当前最高的分：0.893
# 123 3
# (30, 70, 80)
# (30, 70, 80)
# 得分：0.889
# 当前最高的分：0.893
# 124 3
# (30, 70, 90)
# (30, 70, 90)
# 得分：0.829
# 当前最高的分：0.893
# 125 3
# (30, 70, 100)
# (30, 70, 100)
# 得分：0.869
# 当前最高的分：0.893
# 126 3
# (30, 80, 40)
# (30, 80, 40)
# 得分：0.880
# 当前最高的分：0.893
# 127 3
# (30, 80, 50)
# (30, 80, 50)
# 得分：0.857
# 当前最高的分：0.893
# 128 3
# (30, 80, 60)
# (30, 80, 60)
# 得分：0.881
# 当前最高的分：0.893
# 129 3
# (30, 80, 70)
# (30, 80, 70)
# 得分：0.792
# 当前最高的分：0.893
# 130 3
# (30, 80, 80)
# (30, 80, 80)
# 得分：0.875
# 当前最高的分：0.893
# 131 3
# (30, 80, 90)
# (30, 80, 90)
# 得分：0.883
# 当前最高的分：0.893
# 132 3
# (30, 80, 100)
# (30, 80, 100)
# 得分：0.833
# 当前最高的分：0.893
# 133 3
# (30, 90, 40)
# (30, 90, 40)
# 得分：0.839
# 当前最高的分：0.893
# 134 3
# (30, 90, 50)
# (30, 90, 50)
# 得分：0.838
# 当前最高的分：0.893
# 135 3
# (30, 90, 60)

# %% [markdown]
# ## Analysing the Result

# %%
y_predict = best_predict

# %%
KL = scipy.stats.entropy(y_test,y_predict)
print(KL)
# Out:
# 0.0165993543128105

# %%
cengindex = 0
for wi in best_clf.coefs_:
    cengindex += 1  
    print('第%d层网络层:' % cengindex)
    print('权重矩阵维度:',wi.shape)
    print('系数矩阵：\n',wi)
# Out:
# 第1层网络层:
# 权重矩阵维度: (42, 80)
# 系数矩阵：
#  [[-0.0965635   0.21174233  0.26677967 ... -0.1262114   0.15185377
#    0.2242922 ]
#  [-0.0937594  -0.11911556  0.06230213 ... -0.00906249  0.1037179
#   -0.11457276]
#  [-0.05809167 -0.18953843 -0.09598357 ...  0.06539615  0.2263984
#    0.18160742]
#  ...
#  [ 0.03858583  0.04812656 -0.1074884  ... -0.180113   -0.10794377
#    0.248306  ]
#  [ 0.05560405  0.02301889 -0.02617183 ...  0.02432671 -0.15734564
#    0.24607578]
#  [-0.01004004 -0.13712823  0.02015328 ... -0.21967694  0.14557517
#   -0.00659107]]
# 第2层网络层:
# 权重矩阵维度: (80, 100)
# 系数矩阵：
#  [[-0.02576923  0.19209621 -0.00825913 ...  0.04182411  0.27521849
#    0.06576562]
#  [-0.00715799  0.20340508  0.16771922 ...  0.00102797  0.21339514
#    0.21612347]
#  [-0.01123413  0.10768885  0.18033689 ...  0.18463166  0.20450093
#    0.1633013 ]
#  ...
#  [ 0.04281104  0.19386131  0.18679397 ...  0.3435838   0.20679826
#    0.48948355]
#  [-0.02762256  0.14738743  0.13915294 ... -0.05446988 -0.02060728
#    0.11277661]
#  [-0.02402221  0.02380005  0.26636219 ...  0.15482424  0.12854385
#    0.14318205]]
# 第3层网络层:
# 权重矩阵维度: (100, 100)
# 系数矩阵：
#  [[-1.80521871e-02  8.12784792e-05 -1.38918849e-04 ... -9.66786966e-03
#   -2.47041178e-02 -2.41284025e-02]
#  [ 2.77012793e-01 -3.20460027e-02  1.52283389e-01 ...  3.18057183e-01
#    2.42823009e-01  6.93999738e-02]
#  [ 5.90080459e-02 -3.10526617e-02  3.92396468e-02 ...  2.53545839e-01
#    8.09686082e-02  3.30277542e-01]
#  ...
#  [ 3.06130804e-01 -3.00753763e-02 -1.61836382e-01 ... -3.01601827e-03
#    2.42549822e-01  2.47443130e-01]
#  [ 3.34503072e-01 -3.08297140e-02  2.54775604e-02 ...  2.63766785e-01
#    3.08582375e-01  3.26748693e-01]
#  [ 3.23345278e-01 -1.88941004e-02 -4.63828162e-02 ...  1.28418291e-01
#    2.70530196e-01  6.74527196e-02]]
# 第4层网络层:
# 权重矩阵维度: (100, 1)
# 系数矩阵：
#  [[ 2.40902189e-01]
#  [ 2.72069582e-02]
#  [-1.31321081e-01]
#  [ 2.83940751e-01]
#  [-9.46186493e-02]
#  [ 2.73210912e-01]
#  [-1.37995949e-01]
#  [ 2.44762878e-01]
#  [ 2.10765798e-04]
#  [ 2.81003104e-01]
#  [ 1.95474387e-01]
#  [ 2.04841493e-01]
#  [ 2.02926186e-01]
#  [-1.45248397e-01]
#  [-1.36173903e-03]
#  [-1.07183223e-01]
#  [ 2.76920402e-01]
#  [ 2.45023939e-01]
#  [-2.69295438e-02]
#  [-1.47558861e-01]
#  [ 2.25750558e-01]
#  [ 1.98423055e-01]
#  [-1.04556898e-04]
#  [ 2.94515554e-01]
#  [ 4.23588326e-01]
#  [ 2.83635024e-04]
#  [ 3.50014254e-03]
#  [-9.86428719e-02]
#  [-3.26178130e-02]
#  [-1.92376106e-01]
#  [ 3.00571637e-01]
#  [-1.51717536e-01]
#  [ 1.90577895e-04]
#  [ 6.00817185e-04]
#  [-1.98773286e-01]
#  [ 2.08143446e-01]
#  [ 3.19717056e-01]
#  [ 2.66973975e-01]
#  [ 6.58916599e-04]
#  [-3.58883268e-02]
#  [-2.17442914e-01]
#  [-1.82161275e-01]
#  [-2.58854427e-02]
#  [ 1.68374866e-03]
#  [-1.43571353e-01]
#  [ 2.73514043e-01]
#  [-3.23964500e-02]
#  [-3.25754794e-02]
#  [ 9.07237500e-02]
#  [ 3.75372408e-01]
#  [-2.46040037e-02]
#  [ 3.85323803e-01]
#  [ 2.94559587e-01]
#  [-2.76848092e-02]
#  [-4.23222493e-02]
#  [ 4.12185443e-01]
#  [-3.26366181e-02]
#  [ 2.10537446e-01]
#  [ 4.15854088e-01]
#  [ 1.00513349e-03]
#  [ 2.91768559e-01]
#  [-9.79271692e-02]
#  [ 3.61705431e-05]
#  [-2.18996462e-01]
#  [ 4.18005205e-01]
#  [-1.74580922e-02]
#  [ 3.89366066e-01]
#  [-1.44508950e-04]
#  [ 2.07869349e-05]
#  [-1.57808716e-01]
#  [ 3.79051036e-01]
#  [-2.10954459e-02]
#  [ 5.42812230e-05]
#  [ 2.31168436e-01]
#  [ 4.04277658e-01]
#  [-1.29715971e-01]
#  [ 2.30680590e-01]
#  [-1.04078548e-01]
#  [ 1.63220002e-03]
#  [-1.54756366e-01]
#  [-6.70384512e-02]
#  [-5.20054261e-02]
#  [ 3.87891732e-01]
#  [ 3.98550274e-01]
#  [-2.15542398e-01]
#  [ 2.33181317e-01]
#  [ 9.57345517e-01]
#  [ 2.86284257e-01]
#  [-1.85275812e-01]
#  [-9.93588254e-03]
#  [-2.16473672e-01]
#  [ 9.49196589e-05]
#  [ 2.00569318e-01]
#  [ 2.16431999e-02]
#  [ 2.59140168e-01]
#  [ 2.66911992e-01]
#  [ 3.29283040e-01]
#  [ 3.18529970e-01]
#  [ 4.13060593e-01]
#  [ 2.63919303e-01]]

# %%
Y_predict = pd.DataFrame(y_predict)
Y_test = pd.DataFrame(y_test )
